# %% [markdown]
# <a href="https://colab.research.google.com/github/kbee181756/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/Saturday_Copy_of_LS_DS_112_Make_Features_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
##### Begin Working Here #####

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/ryanleeallred/datasets/master/Ames%20Housing%20Data/train.csv')

# %%
df.head()

# %%
pd.set_option("display.max_rows", 100)
df.dtypes

# %%
df["BedroomAbvGr"].head(10)

# %%
df.BedroomAbvGr.head(10)

# %%
df[["BedroomAbvGr", "Fireplaces"]].head(10)

# %%
df["LotFrontage"].head(10)

# %%
import numpy as np

# %%
df["LotFrontage"].value_counts(dropna=False)

# %%
type(np.nan)

# %%
small_df = df[["TotalBsmtSF", "1stFlrSF", "2ndFlrSF", "SalePrice"]].copy()
small_df.head()

# %%
small_df["TotalSquareFootage"] = small_df["TotalBsmtSF"]+ small_df['1stFlrSF']+ small_df["2ndFlrSF"]
small_df.head()

# %%
small_df["PricePerSqFt"] = small_df["SalePrice"] / small_df["TotalSquareFootage"]
small_df.head()

# %%
# Working with String

# %%
! wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2020-01-18 16:40:02--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 64.48.1.20
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|64.48.1.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip’
#
# LoanStats_2018Q4.cs     [  <=>               ]  21.72M  1.56MB/s    in 14s
#
# 2020-01-18 16:40:15 (1.60 MB/s) - ‘LoanStats_2018Q4.csv.zip’ saved [22776791]

# %%
! unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
#   inflating: LoanStats_2018Q4.csv

# %%
import pandas as pd

# %%
df_lc = pd.read_csv("LoanStats_2018Q4.csv", header=1, skipfooter=2)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
df_lc.head()
# Out:
#    id  member_id  ...  settlement_percentage  settlement_term
# 0 NaN        NaN  ...                  60.01             24.0
# 1 NaN        NaN  ...                    NaN              NaN
# 2 NaN        NaN  ...                    NaN              NaN
# 3 NaN        NaN  ...                    NaN              NaN
# 4 NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
pd.set_option("display.max_rows", 200)
df_lc.isnull().sum().sort_values(ascending=True)
# Out:
# inq_fi                                             0
# delinq_amnt                                        0
# chargeoff_within_12_mths                           0
# acc_open_past_24mths                               0
# inq_last_12m                                       0
# total_cu_tl                                        0
# total_rev_hi_lim                                   0
# max_bal_bc                                         0
# open_rv_24m                                        0
# open_rv_12m                                        0
# total_bal_il                                       0
# open_il_24m                                        0
# hardship_flag                                      0
# open_act_il                                        0
# open_acc_6m                                        0
# tot_cur_bal                                        0
# tot_coll_amt                                       0
# acc_now_delinq                                     0
# ...

# %%
df_lcone = df_lc.drop(["url", "member_id", "desc", "id"], axis = 1)

# %%
df_lcone.head()
# Out:
#    loan_amnt  funded_amnt  ...  settlement_percentage settlement_term
# 0       6000         6000  ...                  60.01            24.0
# 1      24000        24000  ...                    NaN             NaN
# 2      30000        30000  ...                    NaN             NaN
# 3       8000         8000  ...                    NaN             NaN
# 4      22400        22400  ...                    NaN             NaN
#
# [5 rows x 140 columns]

# %%
df_lcone["int_rate"].head(10)
# Out:
# 0     14.47%
# 1     10.33%
# 2     15.02%
# 3     12.98%
# 4     16.14%
# 5     12.98%
# 6     15.02%
# 7     16.14%
# 8     14.47%
# 9     13.56%
# Name: int_rate, dtype: object

# %%
df_lcone["int_rate"][3]
# Out:
# ' 12.98%'

# %%
type(df_lcone["int_rate"][3])
# Out:
# str

# %%
int_rate = " 12.98%"

# %%
int_rate.strip()
# Out:
# '12.98%'

# %%
int_rate.strip("%")
# Out:
# ' 12.98'

# %%
int_rate.strip().strip("%")
# Out:
# '12.98'

# %%
float("12.98")
# Out:
# 12.98

# %%
float(int_rate.strip().strip("%"))
# Out:
# 12.98

# %%
type(float(int_rate.strip().strip("%")))
# Out:
# float

# %%
# Write a function

# %%
def myfunc(cell_contents):
  return (float(cell_contents.strip().strip("%")))

# %%
myfunc(int_rate)
# Out:
# 12.98

# %%
# Apply to every cell in column
new_list = []

# %%
# For Loop

for cell in df_lcone["int_rate"]:
  new_list.append(myfunc(cell))

# %%
new_list[:10]
# Out:
# [14.47, 10.33, 15.02, 12.98, 16.14, 12.98, 15.02, 16.14, 14.47, 13.56]

# %%
# Convert List to a new column

# %%
df_lcone["int_rate_cleaned"] = pd.Series(new_list)
df_lcone.head()
# Out:
#    loan_amnt  funded_amnt  ...  settlement_term int_rate_cleaned
# 0       6000         6000  ...             24.0            14.47
# 1      24000        24000  ...              NaN            10.33
# 2      30000        30000  ...              NaN            15.02
# 3       8000         8000  ...              NaN            12.98
# 4      22400        22400  ...              NaN            16.14
#
# [5 rows x 141 columns]

# %%
df_lcone.dtypes
# Out:
# loan_amnt                                       int64
# funded_amnt                                     int64
# funded_amnt_inv                               float64
# term                                           object
# int_rate                                       object
# installment                                   float64
# grade                                          object
# sub_grade                                      object
# emp_title                                      object
# emp_length                                     object
# home_ownership                                 object
# annual_inc                                    float64
# verification_status                            object
# issue_d                                        object
# loan_status                                    object
# pymnt_plan                                     object
# purpose                                        object
# ...

# %%
# Improve code with .apply function

# %%
df_lcone["int_rate_cleaned2"] = df_lcone["int_rate"].apply(myfunc)
df_lcone.head()
# Out:
#    loan_amnt  funded_amnt  ...  int_rate_cleaned int_rate_cleaned2
# 0       6000         6000  ...             14.47             14.47
# 1      24000        24000  ...             10.33             10.33
# 2      30000        30000  ...             15.02             15.02
# 3       8000         8000  ...             12.98             12.98
# 4      22400        22400  ...             16.14             16.14
#
# [5 rows x 142 columns]

# %%
df_lcone["emp_title"].value_counts(dropna=False)[:20]
# Out:
# NaN                   20942
# Teacher                2090
# Manager                1773
# Registered Nurse        951
# Driver                  924
# RN                      726
# Supervisor              697
# Sales                   580
# Project Manager         526
# General Manager         523
# Office Manager          521
# Owner                   420
# Director                402
# Truck Driver            387
# Operations Manager      387
# Nurse                   326
# Engineer                325
# Sales Manager           304
# manager                 301
# Supervisor              270
# Name: emp_title, dtype: int64

# %%
# Unique Employment Titles
df_lcone["emp_title"].unique()
# Out:
# array(['Manager', 'Maintenance Manager', 'Firefighter ', ...,
#        'Oncology Medical Assistant', 'Tax Consultant', 'Payoff Clerk'],
#       dtype=object)

# %%
len(df_lcone["emp_title"].unique())
# Out:
# 43890

# %%
df_lcone["emp_title"].isnull().sum()
# Out:
# 20942

# %%
import numpy as np

# %%
examples = ["owner", "Supervisor", "Project Manager", np.nan]

# %%
def clean_title(job_title):
  if isinstance(job_title, str):
    return job_title.title().strip()
  else:
    return "Unknown"

# %%
# Create a For Loop
for title in examples:
  print(clean_title(title))
# Out:
# Owner
# Supervisor
# Project Manager
# Unknown

# %%
# Using a list comprehension
[clean_title(title) for title in examples]
# Out:
# ['Owner', 'Supervisor', 'Project Manager', 'Unknown']

# %%
df_lcone["emp_title"] = df_lcone["emp_title"].apply(clean_title)

# %%
df_lcone.head()
# Out:
#    loan_amnt  funded_amnt  ...  int_rate_cleaned int_rate_cleaned2
# 0       6000         6000  ...             14.47             14.47
# 1      24000        24000  ...             10.33             10.33
# 2      30000        30000  ...             15.02             15.02
# 3       8000         8000  ...             12.98             12.98
# 4      22400        22400  ...             16.14             16.14
#
# [5 rows x 142 columns]

# %%
df_lcone["emp_title"].value_counts(ascending=False)[:20]
# Out:
# Unknown               20942
# Teacher                2557
# Manager                2395
# Registered Nurse       1417
# Driver                 1258
# Supervisor             1160
# Truck Driver            920
# Rn                      834
# Office Manager          804
# Sales                   803
# General Manager         791
# Project Manager         720
# Owner                   625
# Director                523
# Operations Manager      518
# Sales Manager           500
# Police Officer          440
# Nurse                   424
# Technician              420
# Engineer                412
# Name: emp_title, dtype: int64

# %%
len(df_lcone["emp_title"].unique())
# Out:
# 34899

# %%
df_lcone["emp_title"].isnull().sum()
# Out:
# 0

# %%
df_lcone.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length',
#        ...
#        'hardship_last_payment_amount', 'debt_settlement_flag',
#        'debt_settlement_flag_date', 'settlement_status', 'settlement_date',
#        'settlement_amount', 'settlement_percentage', 'settlement_term',
#        'int_rate_cleaned', 'int_rate_cleaned2'],
#       dtype='object', length=142)

# %%
mylist = []
for col in df_lcone:
  if col.endswith("_d"):
    mylist.append(col)

# %%
print(mylist)
# Out:
# ['issue_d', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d']

# %%
print(df_lcone["issue_d"][:0])
# Out:
# Series([], Name: issue_d, dtype: object)

# %%
mycols = [col for col in df_lcone.columns if col.endswith("_d")]

# %%
print(mycols)
# Out:
# ['issue_d', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d']

# %%
df_lcone["issue_d"][:10]
# Out:
# 0    Dec-2018
# 1    Dec-2018
# 2    Dec-2018
# 3    Dec-2018
# 4    Dec-2018
# 5    Dec-2018
# 6    Dec-2018
# 7    Dec-2018
# 8    Dec-2018
# 9    Dec-2018
# Name: issue_d, dtype: object

# %%
df_lcone["issue_d"] = pd.to_datetime(df_lcone["issue_d"], infer_datetime_format=True)
df_lcone[mycols].head()
# Out:
#      issue_d last_pymnt_d next_pymnt_d last_credit_pull_d
# 0 2018-12-01     Apr-2019          NaN           Nov-2019
# 1 2018-12-01     Dec-2019     Jan-2020           Nov-2019
# 2 2018-12-01     Feb-2019          NaN           Nov-2019
# 3 2018-12-01     Dec-2019     Jan-2020           Dec-2019
# 4 2018-12-01     Dec-2019     Jan-2020           Nov-2019

# %%
df_lcone["issue_d"].iloc[0]
# Out:
# Timestamp('2018-12-01 00:00:00')

# %%
df_lcone["issue_d"].head().values
# Out:
# array(['2018-12-01T00:00:00.000000000', '2018-12-01T00:00:00.000000000',
#        '2018-12-01T00:00:00.000000000', '2018-12-01T00:00:00.000000000',
#        '2018-12-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
# Feature Engineering with dt accessor

# %%
df_lcone=df_lcone[mycols].copy()
df_lcone["year"] = df_lcone["issue_d"].dt.year
df_lcone.head()
# Out:
#      issue_d last_pymnt_d next_pymnt_d last_credit_pull_d  year
# 0 2018-12-01     Apr-2019          NaN           Nov-2019  2018
# 1 2018-12-01     Dec-2019     Jan-2020           Nov-2019  2018
# 2 2018-12-01     Feb-2019          NaN           Nov-2019  2018
# 3 2018-12-01     Dec-2019     Jan-2020           Dec-2019  2018
# 4 2018-12-01     Dec-2019     Jan-2020           Nov-2019  2018

# %%
df_lcone=df_lcone[mycols].copy()
df_lcone["month"] = df_lcone["issue_d"].dt.month
df_lcone.head()
# Out:
#      issue_d last_pymnt_d next_pymnt_d last_credit_pull_d  month
# 0 2018-12-01     Apr-2019          NaN           Nov-2019     12
# 1 2018-12-01     Dec-2019     Jan-2020           Nov-2019     12
# 2 2018-12-01     Feb-2019          NaN           Nov-2019     12
# 3 2018-12-01     Dec-2019     Jan-2020           Dec-2019     12
# 4 2018-12-01     Dec-2019     Jan-2020           Nov-2019     12

# %%
df_lcone.dtypes[-2:]
# Out:
# last_credit_pull_d    object
# month                  int64
# dtype: object

# %%
df_lcone["last_credit_pull_d"] = pd.to_datetime(df_lcone["last_credit_pull_d"], infer_datetime_format=True)
df_lcone.head()
# Out:
#      issue_d last_pymnt_d next_pymnt_d last_credit_pull_d  month
# 0 2018-12-01     Apr-2019          NaN         2019-11-01     12
# 1 2018-12-01     Dec-2019     Jan-2020         2019-11-01     12
# 2 2018-12-01     Feb-2019          NaN         2019-11-01     12
# 3 2018-12-01     Dec-2019     Jan-2020         2019-12-01     12
# 4 2018-12-01     Dec-2019     Jan-2020         2019-11-01     12

# %%
# Date Arithmetic

# %%
df_lcone["last_credit_pull_d"]- df_lcone["issue_d"]
# Out:
# 0        335 days
# 1        335 days
# 2        335 days
# 3        365 days
# 4        335 days
#            ...
# 128392    31 days
# 128393   396 days
# 128394   396 days
# 128395   396 days
# 128396   396 days
# Length: 128397, dtype: timedelta64[ns]

# %%
df_lcone["day_diff"] = (df_lcone["last_credit_pull_d"] - df_lcone["issue_d"]).dt.days
df_lcone.head()
# Out:
#      issue_d last_pymnt_d next_pymnt_d last_credit_pull_d  month  day_diff
# 0 2018-12-01     Apr-2019          NaN         2019-11-01     12     335.0
# 1 2018-12-01     Dec-2019     Jan-2020         2019-11-01     12     335.0
# 2 2018-12-01     Feb-2019          NaN         2019-11-01     12     335.0
# 3 2018-12-01     Dec-2019     Jan-2020         2019-12-01     12     365.0
# 4 2018-12-01     Dec-2019     Jan-2020         2019-11-01     12     335.0

# %%
df_lc["term"].head()
# Out:
# 0     36 months
# 1     36 months
# 2     36 months
# 3     36 months
# 4     60 months
# Name: term, dtype: object

# %%
type(df_lc["term"][2])
# Out:
# str

# %%
term = " 36 months"

# %%
term.strip()
# Out:
# '36 months'

# %%
term.strip("months")
# Out:
# ' 36 '

# %%
float(" 36 ")
# Out:
# 36.0

# %%
float(term.strip().strip("months"))
# Out:
# 36.0

# %%
type(float(term.strip().strip("months")))
# Out:
# float

# %%
def myfucct(cell_contents_2):
  return float(cell_contents_2.strip().strip("months"))

# %%
myfucct(term)
# Out:
# 36.0

# %%
type(myfucct(term))
# Out:
# float

# %%
newer_list = []

# %%
for cell2 in df_lc["term"]:
  newer_list.append(myfucct(cell2))

# %%
newer_list[:10]
# Out:
# [36.0, 36.0, 36.0, 36.0, 60.0, 36.0, 60.0, 36.0, 36.0, 60.0]

# %%
df_lc["term"] = pd.Series(newer_list)

# %%
df_lc.head()
# Out:
#    id  member_id  ...  settlement_percentage  settlement_term
# 0 NaN        NaN  ...                  60.01             24.0
# 1 NaN        NaN  ...                    NaN              NaN
# 2 NaN        NaN  ...                    NaN              NaN
# 3 NaN        NaN  ...                    NaN              NaN
# 4 NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
df_lc["loan_status"].head(50)
# Out:
# 0            Charged Off
# 1                Current
# 2             Fully Paid
# 3                Current
# 4                Current
# 5                Current
# 6                Current
# 7                Current
# 8                Current
# 9                Current
# 10               Current
# 11               Current
# 12               Current
# 13            Fully Paid
# 14               Current
# 15            Fully Paid
# 16               Current
# 17               Current
# 18               Current
# 19    Late (31-120 days)
# 20               Current
# 21               Current
# 22           Charged Off
# 23            Fully Paid
# 24               Current
# 25            Fully Paid
# 26               Current
# 27            Fully Paid
# 28               Current
# 29               Current
# 30               Current
# 31            Fully Paid
# 32            Fully Paid
# 33            Fully Paid
# 34               Current
# 35            Fully Paid
# 36               Current
# ...

# %%
df_lc["loan_status"].unique()
# Out:
# array(['Charged Off', 'Current', 'Fully Paid', 'Late (31-120 days)',
#        'In Grace Period', 'Late (16-30 days)', 'Default'], dtype=object)

# %%
df_lc["loan_status"].value_counts()
# Out:
# Current               97694
# Fully Paid            21476
# Charged Off            5260
# Late (31-120 days)     2656
# In Grace Period         784
# Late (16-30 days)       524
# Default                   3
# Name: loan_status, dtype: int64

# %%
cases = ["Current", "Fully Paid", "Charged Off", "Late (31-120 days)", "In Grace Period", "Late (16-30 days)", "Default"]

# %%
print(cases)
# Out:
# ['Current', 'Fully Paid', 'Charged Off', 'Late (31-120 days)', 'In Grace Period', 'Late (16-30 days)', 'Default']

# %%
def Lstatus(loan_status_update):
  if isinstance(loan_status_update, int):
    return loan_status_update
  else:
    return "0"

# %%
def Lstatus(loan_status_update):
  if isinstance(loan_status_update, str("Fully Paid")):
    return loan_status_update cases:
  if isinstance(loan_status_update, str("Current")):
    return loan_status_update cases:
  else:
    return "0"
# Out:
#   File "<ipython-input-157-4e5667246261>", line 3
#     return loan_status_update cases:
#                                   ^
# SyntaxError: invalid syntax

# %%
Lstatus(cases)
# Out:
# '0'

# %%
status_list = []
for status in cases:
  status_list.append(Lstatus(status))

# %%
df_lc["loan_status_is_great"] = df_lc["pymnt_plan"].apply(Lstatus)
df_lc.head(10)
# Out:
#    id  member_id  ...  settlement_term  loan_status_is_great
# 0 NaN        NaN  ...             24.0                     0
# 1 NaN        NaN  ...              NaN                     0
# 2 NaN        NaN  ...              NaN                     0
# 3 NaN        NaN  ...              NaN                     0
# 4 NaN        NaN  ...              NaN                     0
# 5 NaN        NaN  ...              NaN                     0
# 6 NaN        NaN  ...              NaN                     0
# 7 NaN        NaN  ...              NaN                     0
# 8 NaN        NaN  ...              NaN                     0
# 9 NaN        NaN  ...              NaN                     0
#
# [10 rows x 145 columns]

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %%
df_lcone.head() # "rev_util"
# Out:
#      issue_d last_pymnt_d next_pymnt_d last_credit_pull_d  month  day_diff
# 0 2018-12-01     Apr-2019          NaN         2019-11-01     12     335.0
# 1 2018-12-01     Dec-2019     Jan-2020         2019-11-01     12     335.0
# 2 2018-12-01     Feb-2019          NaN         2019-11-01     12     335.0
# 3 2018-12-01     Dec-2019     Jan-2020         2019-12-01     12     365.0
# 4 2018-12-01     Dec-2019     Jan-2020         2019-11-01     12     335.0

# %%
df_lcone.h

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# %cd instacart_2017_05_01
